# %%
from ml4e.datasets.respiratory import getKaggleRespiratoryDataset

path = getKaggleRespiratoryDataset()
# Out:
# respiratory-sound-database.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  /home/rakshit/ml4e/ml4e/data/archive/respiratory-sound-database.zip
# replace /home/rakshit/ml4e/ml4e/data/respiratory-sound-database/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/101_1b1_Al_sc_Meditron.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:  NULL
# (EOF or read error, treating as "[N]one" ...)

# %%
path
# Out:
# '/home/rakshit/ml4e/ml4e/data/respiratory-sound-database'

# %%
from ml4e.datasets.respiratory import KaggleRespiratoryDataset

data = KaggleRespiratoryDataset()
# Out:
# respiratory-sound-database.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  /home/rakshit/ml4e/ml4e/data/archive/respiratory-sound-database.zip
# replace /home/rakshit/ml4e/ml4e/data/respiratory-sound-database/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/101_1b1_Al_sc_Meditron.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:  NULL
# (EOF or read error, treating as "[N]one" ...)
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# ...
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])
# /home/rakshit/ml4e/ml4e/datasets/respiratory.py:35: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.data.append([int(pID), torch.tensor(np.array(D, dtype=np.float32)), cycles, diag])

# %%
data[0]
# Out:
# [138,
#  tensor([[ 0.0000e+00,  0.0000e+00,  2.7332e-07,  ..., -5.4425e+01,
#            8.9312e+00,  7.2782e+01],
#          [ 0.0000e+00,  0.0000e+00,  1.5325e-07,  ...,  1.0221e+02,
#           -2.9157e+01, -4.8936e+01],
#          [ 0.0000e+00,  0.0000e+00, -1.2248e-07,  ..., -1.1985e+02,
#            7.7836e+01,  3.4491e+01],
#          ...,
#          [ 0.0000e+00,  0.0000e+00, -2.9974e-06,  ...,  2.9405e-07,
#            2.6783e-02, -9.9279e-02],
#          [ 0.0000e+00,  0.0000e+00, -2.8945e-06,  ...,  9.9166e-07,
#           -2.6104e-02,  1.6944e-01],
#          [ 0.0000e+00,  0.0000e+00, -2.8663e-06,  ..., -1.8318e-06,
#           -5.2657e-02, -1.9506e-01]]),
#  array([[ 0.109,  2.529,  1.   ,  0.   ],
#         [ 2.529,  6.786,  0.   ,  1.   ],
#         [ 6.786, 10.826,  1.   ,  0.   ],
#         [10.826, 14.967,  0.   ,  0.   ],
#         [14.967, 18.723,  0.   ,  0.   ]]),
#  'COPD']
